# %%
from beattracker_rp import beatTracker
# Out:
# /home/nikhil/jukedrummer/jd1/lib/python3.12/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)

# %%
x, embeddings = beatTracker('/home/nikhil/jukedrummer/data/segment_audio/target/37_segment_1_0.wav', checkpoint_file='/home/nikhil/jukedrummer/offline_tcn', downbeats=False)
# Out:
# (1, 476, 1) (1, 16, 476)

# %%
print(embeddings.shape)
# Out:
# (1, 16, 476)
